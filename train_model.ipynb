# %%
import os
import torch
from torch import nn
from torch import optim
from torchmetrics import Accuracy
from torch.utils.data import DataLoader
from generate_landmark_data import label_dict_from_config_file
from custom_nn_utils import CustomImageDataset, NeuralNetwork, EarlyStopper

# %%
DATA_FOLDER_PATH = "./data/"
list_label = label_dict_from_config_file("hand_gesture.yaml")
train_path = os.path.join(DATA_FOLDER_PATH, "landmark_train.csv")
val_path = os.path.join(DATA_FOLDER_PATH, "landmark_val.csv")
test_path = os.path.join(DATA_FOLDER_PATH, "landmark_test.csv")
save_path = "models"
os.makedirs(save_path, exist_ok=True)

# %%
trainset = CustomImageDataset(train_path)
trainloader = DataLoader(trainset, batch_size=40, shuffle=True)

valset = CustomImageDataset(os.path.join(val_path))
val_loader = DataLoader(valset , batch_size=50, shuffle=False)

testset = CustomImageDataset(test_path)
test_loader = DataLoader(testset, batch_size=20, shuffle=False)

# %%
def train(trainloader, val_loader, model, loss_function, early_stopper, optimizer, max_epochs=300, save_path="models"):
    best_vloss = float("inf")
    best_model_path = None

    for epoch in range(max_epochs):
        # Training phase
        model.train(True)
        running_loss = 0.0
        acc_train = Accuracy(num_classes=len(list_label), task="multiclass") # Track training accuracy
        
        for inputs, labels in trainloader:
            optimizer.zero_grad()  # Reset gradients
            preds = model(inputs)  # Forward pass
            loss = loss_function(preds, labels)  # Compute loss
            loss.backward()  # Backward pass
            optimizer.step()  # Update model parameters

            acc_train.update(model.predict_with_known_class(inputs), labels)  # Update training accuracy
            running_loss += loss.item()  # Sum training loss

        avg_loss = running_loss / len(trainloader)  # Average training loss
        
        # Validation phase
        model.eval()
        running_vloss = 0.0
        acc_val = Accuracy(num_classes=len(list_label), task="multiclass")  # Track validation accuracy
        
        with torch.no_grad():
            for vinputs, vlabels in val_loader:
                preds = model(vinputs)  # Forward pass
                vloss = loss_function(preds, vlabels)  # Compute validation loss
                acc_val.update(model.predict_with_known_class(vinputs), vlabels)  # Update validation accuracy
                running_vloss += vloss.item()  # Sum validation loss

        avg_vloss = running_vloss / len(val_loader)  # Average validation loss

        # Log metrics for the epoch
        print(f"Epoch {epoch}:")
        print(f"Accuracy - Train: {acc_train.compute().item():.4f}, Val: {acc_val.compute().item():.4f}")
        print(f"Loss - Train: {avg_loss:.4f}, Val: {avg_vloss:.4f}\n")

        # Save the best model based on validation loss
        if avg_vloss < best_vloss:
            best_vloss = avg_vloss
            best_model_path = os.path.join(save_path, "best_model.pth")
            print(f"Saving best model to {best_model_path}")
            torch.save(model.state_dict(), best_model_path)

        # Check if early stopping condition is met
        if early_stopper.early_stop(avg_vloss):
            print(f"Stopping training at epoch {epoch}, min val_loss: {early_stopper.watched_metrics:.4f}")
            break

    # Save the last model after training
    model_path = os.path.join(save_path, "last_model.pth")
    print(f"Saving last model to {model_path}")
    torch.save(model.state_dict(), model_path)

    return model, best_model_path

# %%
model = NeuralNetwork()
loss_function = nn.CrossEntropyLoss()
early_stopper = EarlyStopper(patience=30, min_delta=0.01)

optimizer = optim.Adam(model.parameters(), lr=0.0001)

model, best_model_path = train(trainloader, val_loader, model, loss_function, early_stopper, optimizer)
# Out:
# Epoch 0:
# Accuracy - Train: 0.3385, Val: 0.5125
# Loss - Train: 1.5520, Val: 1.4078
#
# Saving best model to models\best_model.pth
# Epoch 1:
# Accuracy - Train: 0.5086, Val: 0.7159
# Loss - Train: 1.1989, Val: 0.7027
#
# Saving best model to models\best_model.pth
# Epoch 2:
# Accuracy - Train: 0.7751, Val: 0.8798
# Loss - Train: 0.6705, Val: 0.3357
#
# Saving best model to models\best_model.pth
# Epoch 3:
# Accuracy - Train: 0.9232, Val: 0.9736
# Loss - Train: 0.3201, Val: 0.1479
#
# Saving best model to models\best_model.pth
# Epoch 4:
# Accuracy - Train: 0.9830, Val: 0.9793
# Loss - Train: 0.1463, Val: 0.0610
#
# Saving best model to models\best_model.pth
# Epoch 5:
# Accuracy - Train: 0.9851, Val: 0.9798
# Loss - Train: 0.0761, Val: 0.0533
#
# Saving best model to models\best_model.pth
# Epoch 6:
# Accuracy - Train: 0.9890, Val: 0.9846
# Loss - Train: 0.0604, Val: 0.0440
#
# Saving best model to models\best_model.pth
# Epoch 7:
# Accuracy - Train: 0.9881, Val: 0.9880
# Loss - Train: 0.0465, Val: 0.0343
#
# Saving best model to models\best_model.pth
# Epoch 8:
# Accuracy - Train: 0.9890, Val: 0.9861
# Loss - Train: 0.0524, Val: 0.0543
#
# Epoch 9:
# Accuracy - Train: 0.9923, Val: 0.9837
# Loss - Train: 0.0425, Val: 0.0578
#
# Epoch 10:
# Accuracy - Train: 0.9918, Val: 0.9846
# Loss - Train: 0.0384, Val: 0.0488
#
# Epoch 11:
# Accuracy - Train: 0.9923, Val: 0.9851
# Loss - Train: 0.0351, Val: 0.0564
#
# Epoch 12:
# Accuracy - Train: 0.9930, Val: 0.9875
# Loss - Train: 0.0337, Val: 0.0505
#
# Epoch 13:
# Accuracy - Train: 0.9911, Val: 0.9851
# Loss - Train: 0.0310, Val: 0.0534
#
# Epoch 14:
# Accuracy - Train: 0.9918, Val: 0.9856
# Loss - Train: 0.0370, Val: 0.0551
#
# Epoch 15:
# Accuracy - Train: 0.9946, Val: 0.9841
# Loss - Train: 0.0293, Val: 0.0654
#
# Epoch 16:
# Accuracy - Train: 0.9925, Val: 0.9861
# Loss - Train: 0.0281, Val: 0.0533
#
# Epoch 17:
# Accuracy - Train: 0.9925, Val: 0.9841
# Loss - Train: 0.0345, Val: 0.0555
#
# Epoch 18:
# Accuracy - Train: 0.9944, Val: 0.9865
# Loss - Train: 0.0227, Val: 0.0483
#
# Epoch 19:
# Accuracy - Train: 0.9935, Val: 0.9889
# Loss - Train: 0.0251, Val: 0.0410
#
# Epoch 20:
# Accuracy - Train: 0.9935, Val: 0.9875
# Loss - Train: 0.0255, Val: 0.0459
#
# Epoch 21:
# Accuracy - Train: 0.9935, Val: 0.9865
# Loss - Train: 0.0286, Val: 0.0404
#
# Epoch 22:
# Accuracy - Train: 0.9918, Val: 0.9865
# Loss - Train: 0.0305, Val: 0.0374
#
# Epoch 23:
# Accuracy - Train: 0.9958, Val: 0.9865
# Loss - Train: 0.0229, Val: 0.0542
#
# Epoch 24:
# Accuracy - Train: 0.9939, Val: 0.9865
# Loss - Train: 0.0225, Val: 0.0446
#
# Epoch 25:
# Accuracy - Train: 0.9935, Val: 0.9889
# Loss - Train: 0.0246, Val: 0.0345
#
# Epoch 26:
# Accuracy - Train: 0.9939, Val: 0.9889
# Loss - Train: 0.0229, Val: 0.0378
#
# Epoch 27:
# Accuracy - Train: 0.9928, Val: 0.9928
# Loss - Train: 0.0206, Val: 0.0334
#
# Saving best model to models\best_model.pth
# Epoch 28:
# Accuracy - Train: 0.9939, Val: 0.9856
# Loss - Train: 0.0231, Val: 0.0502
#
# Epoch 29:
# Accuracy - Train: 0.9944, Val: 0.9856
# Loss - Train: 0.0239, Val: 0.0531
#
# Epoch 30:
# Accuracy - Train: 0.9958, Val: 0.9832
# Loss - Train: 0.0158, Val: 0.0618
#
# Epoch 31:
# Accuracy - Train: 0.9958, Val: 0.9851
# Loss - Train: 0.0197, Val: 0.0579
#
# Epoch 32:
# Accuracy - Train: 0.9951, Val: 0.9885
# Loss - Train: 0.0210, Val: 0.0486
#
# Epoch 33:
# Accuracy - Train: 0.9953, Val: 0.9822
# Loss - Train: 0.0181, Val: 0.0590
#
# Epoch 34:
# Accuracy - Train: 0.9939, Val: 0.9856
# Loss - Train: 0.0235, Val: 0.0597
#
# Epoch 35:
# Accuracy - Train: 0.9960, Val: 0.9861
# Loss - Train: 0.0191, Val: 0.0529
#
# Epoch 36:
# Accuracy - Train: 0.9939, Val: 0.9812
# Loss - Train: 0.0203, Val: 0.0605
#
# Epoch 37:
# Accuracy - Train: 0.9942, Val: 0.9870
# Loss - Train: 0.0162, Val: 0.0438
#
# Epoch 38:
# Accuracy - Train: 0.9953, Val: 0.9861
# Loss - Train: 0.0177, Val: 0.0478
#
# Epoch 39:
# Accuracy - Train: 0.9932, Val: 0.9851
# Loss - Train: 0.0187, Val: 0.0511
#
# Epoch 40:
# Accuracy - Train: 0.9949, Val: 0.9837
# Loss - Train: 0.0208, Val: 0.0593
#
# Epoch 41:
# Accuracy - Train: 0.9944, Val: 0.9880
# Loss - Train: 0.0205, Val: 0.0421
#
# Epoch 42:
# Accuracy - Train: 0.9937, Val: 0.9851
# Loss - Train: 0.0208, Val: 0.0485
#
# Epoch 43:
# Accuracy - Train: 0.9960, Val: 0.9880
# Loss - Train: 0.0170, Val: 0.0460
#
# Epoch 44:
# Accuracy - Train: 0.9960, Val: 0.9875
# Loss - Train: 0.0118, Val: 0.0502
#
# Epoch 45:
# Accuracy - Train: 0.9951, Val: 0.9841
# Loss - Train: 0.0154, Val: 0.0491
#
# Epoch 46:
# Accuracy - Train: 0.9956, Val: 0.9856
# Loss - Train: 0.0196, Val: 0.0454
#
# Epoch 47:
# Accuracy - Train: 0.9977, Val: 0.9909
# Loss - Train: 0.0154, Val: 0.0304
#
# Saving best model to models\best_model.pth
# Epoch 48:
# Accuracy - Train: 0.9946, Val: 0.9894
# Loss - Train: 0.0126, Val: 0.0338
#
# Epoch 49:
# Accuracy - Train: 0.9972, Val: 0.9841
# Loss - Train: 0.0309, Val: 0.0704
#
# Epoch 50:
# Accuracy - Train: 0.9946, Val: 0.9832
# Loss - Train: 0.0249, Val: 0.0466
#
# Epoch 51:
# Accuracy - Train: 0.9967, Val: 0.9875
# Loss - Train: 0.0175, Val: 0.0405
#
# Epoch 52:
# Accuracy - Train: 0.9946, Val: 0.9870
# Loss - Train: 0.0144, Val: 0.0449
#
# Epoch 53:
# Accuracy - Train: 0.9956, Val: 0.9880
# Loss - Train: 0.0131, Val: 0.0368
#
# Epoch 54:
# Accuracy - Train: 0.9956, Val: 0.9856
# Loss - Train: 0.0143, Val: 0.0677
#
# Epoch 55:
# Accuracy - Train: 0.9970, Val: 0.9856
# Loss - Train: 0.0149, Val: 0.0502
#
# Epoch 56:
# Accuracy - Train: 0.9951, Val: 0.9841
# Loss - Train: 0.0233, Val: 0.0547
#
# Epoch 57:
# Accuracy - Train: 0.9949, Val: 0.9856
# Loss - Train: 0.0180, Val: 0.0554
#
# Epoch 58:
# Accuracy - Train: 0.9956, Val: 0.9832
# Loss - Train: 0.0170, Val: 0.0620
#
# Epoch 59:
# Accuracy - Train: 0.9960, Val: 0.9841
# Loss - Train: 0.0134, Val: 0.0613
#
# Epoch 60:
# Accuracy - Train: 0.9963, Val: 0.9846
# Loss - Train: 0.0115, Val: 0.0574
#
# Epoch 61:
# Accuracy - Train: 0.9944, Val: 0.9856
# Loss - Train: 0.0178, Val: 0.0552
#
# Epoch 62:
# Accuracy - Train: 0.9963, Val: 0.9841
# Loss - Train: 0.0261, Val: 0.0588
#
# Epoch 63:
# Accuracy - Train: 0.9956, Val: 0.9841
# Loss - Train: 0.0223, Val: 0.0503
#
# Epoch 64:
# Accuracy - Train: 0.9960, Val: 0.9827
# Loss - Train: 0.0116, Val: 0.0747
#
# Epoch 65:
# Accuracy - Train: 0.9963, Val: 0.9865
# Loss - Train: 0.0221, Val: 0.0508
#
# Epoch 66:
# Accuracy - Train: 0.9967, Val: 0.9841
# Loss - Train: 0.0193, Val: 0.0536
#
# Epoch 67:
# Accuracy - Train: 0.9949, Val: 0.9865
# Loss - Train: 0.0188, Val: 0.0557
#
# Epoch 68:
# Accuracy - Train: 0.9963, Val: 0.9880
# Loss - Train: 0.0135, Val: 0.0537
#
# Epoch 69:
# Accuracy - Train: 0.9965, Val: 0.9827
# Loss - Train: 0.0125, Val: 0.0578
#
# Epoch 70:
# Accuracy - Train: 0.9974, Val: 0.9918
# Loss - Train: 0.0144, Val: 0.0290
#
# Saving best model to models\best_model.pth
# Epoch 71:
# Accuracy - Train: 0.9965, Val: 0.9856
# Loss - Train: 0.0117, Val: 0.0575
#
# Epoch 72:
# Accuracy - Train: 0.9965, Val: 0.9856
# Loss - Train: 0.0146, Val: 0.0416
#
# Epoch 73:
# Accuracy - Train: 0.9967, Val: 0.9875
# Loss - Train: 0.0115, Val: 0.0372
#
# Epoch 74:
# Accuracy - Train: 0.9974, Val: 0.9861
# Loss - Train: 0.0101, Val: 0.0400
#
# Epoch 75:
# Accuracy - Train: 0.9981, Val: 0.9875
# Loss - Train: 0.0069, Val: 0.0550
#
# Epoch 76:
# Accuracy - Train: 0.9951, Val: 0.9885
# Loss - Train: 0.0141, Val: 0.0384
#
# Epoch 77:
# Accuracy - Train: 0.9958, Val: 0.9870
# Loss - Train: 0.0121, Val: 0.0425
#
# Epoch 78:
# Accuracy - Train: 0.9965, Val: 0.9880
# Loss - Train: 0.0097, Val: 0.0435
#
# Epoch 79:
# Accuracy - Train: 0.9974, Val: 0.9861
# Loss - Train: 0.0083, Val: 0.0523
#
# Epoch 80:
# Accuracy - Train: 0.9972, Val: 0.9870
# Loss - Train: 0.0093, Val: 0.0630
#
# Epoch 81:
# Accuracy - Train: 0.9974, Val: 0.9841
# Loss - Train: 0.0079, Val: 0.0671
#
# Epoch 82:
# Accuracy - Train: 0.9977, Val: 0.9827
# Loss - Train: 0.0070, Val: 0.0773
#
# Epoch 83:
# Accuracy - Train: 0.9965, Val: 0.9870
# Loss - Train: 0.0114, Val: 0.0568
#
# Epoch 84:
# Accuracy - Train: 0.9958, Val: 0.9875
# Loss - Train: 0.0148, Val: 0.0642
#
# Epoch 85:
# Accuracy - Train: 0.9972, Val: 0.9856
# Loss - Train: 0.0104, Val: 0.0626
#
# Epoch 86:
# Accuracy - Train: 0.9972, Val: 0.9846
# Loss - Train: 0.0094, Val: 0.0763
#
# Epoch 87:
# Accuracy - Train: 0.9965, Val: 0.9880
# Loss - Train: 0.0125, Val: 0.0486
#
# Epoch 88:
# Accuracy - Train: 0.9965, Val: 0.9851
# Loss - Train: 0.0151, Val: 0.0452
#
# Epoch 89:
# Accuracy - Train: 0.9974, Val: 0.9870
# Loss - Train: 0.0108, Val: 0.0592
#
# Epoch 90:
# Accuracy - Train: 0.9979, Val: 0.9856
# Loss - Train: 0.0121, Val: 0.0586
#
# Epoch 91:
# Accuracy - Train: 0.9963, Val: 0.9846
# Loss - Train: 0.0124, Val: 0.0652
#
# Epoch 92:
# Accuracy - Train: 0.9977, Val: 0.9865
# Loss - Train: 0.0085, Val: 0.0439
#
# Epoch 93:
# Accuracy - Train: 0.9979, Val: 0.9875
# Loss - Train: 0.0091, Val: 0.0617
#
# Epoch 94:
# Accuracy - Train: 0.9977, Val: 0.9832
# Loss - Train: 0.0150, Val: 0.0644
#
# Epoch 95:
# Accuracy - Train: 0.9949, Val: 0.9846
# Loss - Train: 0.0223, Val: 0.0728
#
# Epoch 96:
# Accuracy - Train: 0.9965, Val: 0.9837
# Loss - Train: 0.0087, Val: 0.0553
#
# Epoch 97:
# Accuracy - Train: 0.9972, Val: 0.9870
# Loss - Train: 0.0099, Val: 0.0527
#
# Epoch 98:
# Accuracy - Train: 0.9981, Val: 0.9889
# Loss - Train: 0.0308, Val: 0.0442
#
# Epoch 99:
# Accuracy - Train: 0.9960, Val: 0.9861
# Loss - Train: 0.0134, Val: 0.0412
#
# Epoch 100:
# Accuracy - Train: 0.9965, Val: 0.9841
# Loss - Train: 0.0106, Val: 0.0649
#
# Epoch 101:
# Accuracy - Train: 0.9977, Val: 0.9851
# Loss - Train: 0.0089, Val: 0.0630
#
# Epoch 102:
# Accuracy - Train: 0.9977, Val: 0.9861
# Loss - Train: 0.0106, Val: 0.0472
#
# Stopping training at epoch 102, min val_loss: 0.0290
# Saving last model to models\last_model.pth

# %%
# Initialize and load the best model
network = NeuralNetwork()
network.load_state_dict(torch.load(best_model_path, weights_only=False))

# Set the model to evaluation mode
network.eval()

# Initialize the accuracy tracker for multi-class classification
acc_test = Accuracy(num_classes=len(list_label), task="multiclass")

# Iterate through the test set and compute accuracy
for i, test_data in enumerate(test_loader):
    test_input, test_label = test_data
    preds = network(test_input)
    acc_test.update(preds, test_label)

# Print the model class name and accuracy
print(network.__class__.__name__)
print(f"Accuracy of model: {acc_test.compute().item():.4f}")
# Out:
# NeuralNetwork
# Accuracy of model: 0.9899
